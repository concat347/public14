# %% [markdown]
# ### Pyspark Dataframes - Filter Operations, PySpark SQL
#
# 3/18/2024
#
# Answer the TODO items.
# - Filter Operation
# - &,|,==
# -
# - ~
#
# PySpark documentation:
# https://spark.apache.org/docs/latest/api/python/reference/index.html
#
# Answer the TODO items.

# %%
# import os
from pyspark.sql import SparkSession
import pandas as pd

# %%
spark = SparkSession.builder \
    .appName("Intro") \
    .master("local[*]") \
    .getOrCreate()

spark.sparkContext.setLogLevel("ERROR")

print(spark.version)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/04/01 19:14:39 WARN Utils: Your hostname, Alpha, resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 26/04/01 19:14:39 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/01 19:14:39 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/04/01 19:14:40 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 4.1.1

# %%
df_pyspark=spark.read.csv('test1.csv',header=True,inferSchema=True)
df_pyspark.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %% [markdown]
# PySpark SQL
#
# PySpark SQL is one of the most used PySpark modules which is used for processing structured columnar data format. Once you have a DataFrame created, you can interact with the data by using SQL syntax.
#
# In other words, Spark SQL brings native SQL queries on Spark meaning you can run traditional ANSI SQL’s on Spark Dataframe, in the later section of this PySpark SQL tutorial, you will learn in detail using SQL select, where, group by, join, union e.t.c
#
# In order to use SQL, first, create a temporary table on DataFrame using createOrReplaceTempView() function. Once created, this table can be accessed throughout the SparkSession using sql() and it will be dropped along with your SparkContext termination.
#
# Use sql() method of the SparkSession object to run the query and this method returns a new DataFrame.
#
# https://spark.apache.org/docs/3.1.2/api/python/reference/pyspark.sql.html

# %%
df_pyspark.createOrReplaceTempView("PEOPLE")
df1=spark.sql("select Name, age, Experience, Salary as salary from PEOPLE")
df1.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %% [markdown]
# ### Filter Operations

# %%
### Salary of the people less than or equal to 20000
df_pyspark.filter("Salary<=20000").show()
# Out:
# +-------+---+----------+------+
# |   Name|age|Experience|Salary|
# +-------+---+----------+------+
# |  Sunny| 29|         4| 20000|
# |   Paul| 24|         3| 20000|
# | Harsha| 21|         1| 15000|
# |Shubham| 23|         2| 18000|
# +-------+---+----------+------+

# %%
#### TODO: Perform the equivalent operation using PySpark SQL
# SQL query to select people with salary <= 20000
df_sql_filtered = spark.sql("""
    SELECT Name, age, Experience, Salary
    FROM PEOPLE
    WHERE Salary <= 20000
""")

# Show the results
df_sql_filtered.show()
# Out:
# +-------+---+----------+------+
# |   Name|age|Experience|Salary|
# +-------+---+----------+------+
# |  Sunny| 29|         4| 20000|
# |   Paul| 24|         3| 20000|
# | Harsha| 21|         1| 15000|
# |Shubham| 23|         2| 18000|
# +-------+---+----------+------+

# %%
df_pyspark.filter("Salary<20000").select(['Name','age']).show()
# Out:
# +-------+---+
# |   Name|age|
# +-------+---+
# | Harsha| 21|
# |Shubham| 23|
# +-------+---+

# %%
#### TODO: Perform the equivalent operation (above) using PySpark SQL

# Use Spark SQL to select Name and age where Salary < 20000
df_sql_filtered = spark.sql("""
    SELECT Name, age
    FROM PEOPLE
    WHERE Salary < 20000
""")

# Show the results
df_sql_filtered.show()
# Out:
# +-------+---+
# |   Name|age|
# +-------+---+
# | Harsha| 21|
# |Shubham| 23|
# +-------+---+

# %%
df_pyspark.filter(df_pyspark['Salary']<20000).show()
# Out:
# +-------+---+----------+------+
# |   Name|age|Experience|Salary|
# +-------+---+----------+------+
# | Harsha| 21|         1| 15000|
# |Shubham| 23|         2| 18000|
# +-------+---+----------+------+

# %%
df_pyspark.filter((df_pyspark['Salary']<20000) | 
                  (df_pyspark['Salary']>=15000)).show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
#### TODO: Perform the same operation (above) except use logical AND using PySpark Dataframe 

df_pyspark.filter((df_pyspark['Salary'] < 20000) & 
                  (df_pyspark['Salary'] >= 15000)).show()
# Out:
# +-------+---+----------+------+
# |   Name|age|Experience|Salary|
# +-------+---+----------+------+
# | Harsha| 21|         1| 15000|
# |Shubham| 23|         2| 18000|
# +-------+---+----------+------+

# %%
#### TODO: Perform the same operation  (above) logical AND and select pnly the Name and Salary using PySpark SQL 

# Use Spark SQL with logical AND
result = spark.sql("""
    SELECT Name, Salary
    FROM PEOPLE
    WHERE Salary >= 15000 AND Salary < 20000
""")

result.show()
# Out:
# +-------+------+
# |   Name|Salary|
# +-------+------+
# | Harsha| 15000|
# |Shubham| 18000|
# +-------+------+

# %%
df_pyspark.filter(~(df_pyspark['Salary']<=20000)).show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# +---------+---+----------+------+

# %%
#### TODO: Perform the same operation (above) using PySpark Dataframe 

df_pyspark.filter(df_pyspark['Salary'] > 20000).show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# +---------+---+----------+------+
