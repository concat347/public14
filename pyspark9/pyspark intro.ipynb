# %% [markdown]
# ## Pyspark Introduction
#
#
# Jay Urbain, PhD
# 3/15/2024
#
# PySpark documentation:
# https://spark.apache.org/docs/latest/api/python/reference/index.html
#
# Answer the TODO items.

# %% [markdown]
# First you need to make sure jupyter is using the Java installed in your environment. One of the two following options should work.

# %% [markdown]
# Imports

# %%
# import os
from pyspark.sql import SparkSession
import pandas as pd

# %% [markdown]
# Create a Spark Session

# %%
spark = SparkSession.builder \
    .appName("Intro") \
    .master("local[*]") \
    .getOrCreate()

spark.sparkContext.setLogLevel("ERROR")

print(spark.version)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/04/01 19:02:02 WARN Utils: Your hostname, Alpha, resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 26/04/01 19:02:02 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/01 19:02:02 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/04/01 19:02:03 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 4.1.1

# %%
type(pd.read_csv('test1.csv'))
# Out:
# pandas.DataFrame

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.255.255.254:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Intro</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark=spark.read.csv('test1.csv')

# %%
df_pyspark=spark.read.option('header','true').csv('test1.csv')

# %%
type(df_pyspark)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- Experience: string (nullable = true)
#  |-- Salary: string (nullable = true)

# %% [markdown]
# ### TODO: Take a snapshot of yourself patting yourself on the back. Getting the environment right can be tricky!
